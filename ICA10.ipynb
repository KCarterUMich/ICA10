# %% [markdown]
# <a href="https://colab.research.google.com/github/KCarterUMich/ICA10/blob/main/ICA10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# *   Please read titanic.csv from the DATA folder
# *   Change 1s to "Survived" under the Survived column of the data frame by looking at the example provided.
# *   Get rows which don't have "?" under Pclass column and move to the next step.

# %%
titanic = pd.read_csv('/content/drive/MyDrive/DATA/titanic.csv')
titanic.loc[titanic["Survived"] == 0, "Survived"] = "Died"
# Out:
# <ipython-input-3-ec2960f4c8fc>:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Died' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   titanic.loc[titanic["Survived"] == 0, "Survived"] = "Died"

# %%
# prompt: print the data

titanic = titanic[titanic.Pclass != '?']
print(titanic)
# Out:
#      Unnamed: 0  PassengerId Survived Pclass  \
# 0             0            1     Died      3
# 1             1            2        1      1
# 2             2            3        1      3
# 3             3            4        1      1
# 4             4            5     Died      3
# ..          ...          ...      ...    ...
# 885         885          886     Died      3
# 886         886          887     Died      2
# 887         887          888        1      1
# 889         889          890        1      1
# 890         890          891     Died      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [842 rows x 13 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# prompt: Change 1s to "Survived" under the Survived column of the data frame by looking at the example provided.

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

titanic = pd.read_csv('/content/drive/MyDrive/DATA/titanic.csv')
titanic.loc[titanic["Survived"] == 0, "Survived"] = "Died"
titanic.loc[titanic["Survived"] == 1, "Survived"] = "Survived"

titanic = titanic[titanic.Pclass != '?']
print(titanic)

drive.mount('/content/drive')
# Out:
# <ipython-input-5-2abf6814f82a>:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Died' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   titanic.loc[titanic["Survived"] == 0, "Survived"] = "Died"
#      Unnamed: 0  PassengerId  Survived Pclass  \
# 0             0            1      Died      3
# 1             1            2  Survived      1
# 2             2            3  Survived      3
# 3             3            4  Survived      1
# 4             4            5      Died      3
# ..          ...          ...       ...    ...
# 885         885          886      Died      3
# 886         886          887      Died      2
# 887         887          888  Survived      1
# 889         889          890  Survived      1
# 890         890          891      Died      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [842 rows x 13 columns]
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# prompt: Get rows which don't have "?" under Pclass column and move to the next step.

titanic = titanic[titanic.Pclass != "?"]

# %%
# prompt: print

print(titanic)
# Out:
#      Unnamed: 0  PassengerId  Survived Pclass  \
# 0             0            1      Died      3
# 1             1            2  Survived      1
# 2             2            3  Survived      3
# 3             3            4  Survived      1
# 4             4            5      Died      3
# ..          ...          ...       ...    ...
# 885         885          886      Died      3
# 886         886          887      Died      2
# 887         887          888  Survived      1
# 889         889          890  Survived      1
# 890         890          891      Died      3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [842 rows x 13 columns]

# %% [markdown]
# Create a multipanel plot which draws density plots for each class-survived combination. Please also use the hue parameter based on the Sex attribute to have two density plots in each panel with different colors.

# %%
# prompt: Create a multipanel plot which draws density plots for each class-survived combination

import matplotlib.pyplot as plt
g = sns.FacetGrid(titanic, col="Pclass", row = "Survived", hue="Sex")
g.map(sns.kdeplot, "Age", alpha=.7)
g.add_legend()
plt.show()

# %%
# prompt: use the hue parameter based on the Sex attribute to have two density plots in each panel with pink for female and blue for male

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import drive

titanic = pd.read_csv('/content/drive/MyDrive/DATA/titanic.csv')
titanic.loc[titanic["Survived"] == 0, "Survived"] = "Died"
titanic.loc[titanic["Survived"] == 1, "Survived"] = "Survived"

titanic = titanic[titanic.Pclass != '?']

g = sns.FacetGrid(titanic, col="Pclass", row = "Survived", hue="Sex", palette={'male':'blue', 'female':'pink'})
g.map(sns.kdeplot, "Age", alpha=.7)
g.add_legend()
plt.show()
# Out:
# <ipython-input-9-3cb36f5a62c8>:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'Died' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   titanic.loc[titanic["Survived"] == 0, "Survived"] = "Died"

# %%
#you can uncomment below when you come up with your density plots for each class-survived combination
#titles = ['Died in Class 3','Died in Class 1', 'Died in Class 2', 'Survived in Class 3','Survived in Class 1', 'Survived in Class 2']
#for ax,title in zip(g.axes.flatten(),titles):
#    ax.set_title(title )
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:316: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   warnings.warn(msg, UserWarning)

# %%
# prompt: #you can uncomment below when you come up with your density plots for each class-survived combination
# #titles = ['Died in Class 3','Died in Class 1', 'Died in Class 2', 'Survived in Class 3','Survived in Class 1', 'Survived in Class 2']
# #for ax,title in zip(g.axes.flatten(),titles):
# #    ax.set_title(title )

#you can uncomment below when you come up with your density plots for each class-survived combination
titles = ['Died in Class 3','Died in Class 1', 'Died in Class 2', 'Survived in Class 3','Survived in Class 1', 'Survived in Class 2']
for ax,title in zip(g.axes.flatten(),titles):
    ax.set_title(title )
